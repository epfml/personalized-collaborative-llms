# %%
import wandb

api = wandb.Api()
run = api.run(f"cl-AG-S/21jasgv1")
data = run.history(keys=["Trust weights"])

# %%
data
# Out:
#     _step                                      Trust weights
# 0       3  [[1.0, 0.001174800330772996, 0.001022335141897...
# 1       4  [[1.0, 0.003063790500164032, 0.002547160256654...
# 2       5  [[1.0, 0.008034730330109596, 0.006512832362204...
# 3       6  [[1.0, 0.021523915231227875, 0.016938036307692...
# 4       7  [[1.0, 0.058978382498025894, 0.044063083827495...
# 5       8  [[1.0, 0.16348162293434143, 0.1107243373990058...
# 6       9  [[1.0, 0.426371306180954, 0.2541763484477997, ...
# 7      10  [[1.0, 0.9314120411872864, 0.7072964906692505,...
# 8      11  [[NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN], [Na...
# 9      12  [[NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN], [Na...
# 10     13  [[NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN], [Na...
# 11     14  [[NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN], [Na...
# 12     15  [[NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN], [Na...
# 13     16  [[NaN, NaN, NaN, NaN, NaN, NaN, NaN, NaN], [Na...
# ...
